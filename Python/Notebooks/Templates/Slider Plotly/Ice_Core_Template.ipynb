# %% [markdown]
# ```
# Imports
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib.style as style
from plotly import graph_objs as go

# %% [markdown]
# ```
# Load dataset
# ```

# %%
try:
    age, D18O2 = np.loadtxt('D18O2.txt')
    print("Data series loaded!")
except:
    print("Error: Failed to load data series!")
# Out:
# Data series loaded!

# %%
xpoints = np.array([12896,13099,13311,13600,13660,13954,14075,14692,17480,20900,22900,23020,23220,23340,27540,27780,28600,28900,30600,30840,32040,32500,33360,33740,34740,34880,35020,35480,36580,36860,37120,38220,39900,40160,40800,41460,42240,43340,44280,44560,44680,46860,48340,49060,49120,49280,49600,51500,51660,53960,54020,54220,54900,55000,55400,55800,56500,57920,57960,58040,58160,58280,58560,58780,58840,59080,59300,59440,63840,64100,69400,69620,70380,72340,74100,74320,74440,76440,77760,78080,78740,79240,79700,84760,84960,85060,87600,87820,88000,88800,88920,89800,89840,90040,90140,104040,104380,104520,105440,106220,106320,106750,106900,108280,110640,110940,111440,115370,119140])
index = np.searchsorted(age, xpoints)
index = index.tolist()
print(index)
# Out:
# [691, 851, 1002, 1256, 1302, 1571, 1657, 2253, 3543, 5067, 5833, 5886, 5966, 6025, 7395, 7543, 7813, 7992, 8482, 8572, 8954, 9194, 9447, 9652, 9966, 10036, 10102, 10350, 10694, 10814, 10925, 11561, 12054, 12153, 12355, 12641, 12860, 13310, 13561, 13657, 13693, 14607, 14980, 15217, 15237, 15299, 15390, 16026, 16079, 16968, 16988, 17071, 17234, 17267, 17353, 17487, 17649, 18096, 18108, 18136, 18167, 18211, 18281, 18356, 18373, 18461, 18514, 18569, 19397, 19477, 20258, 20312, 20411, 20880, 21111, 21153, 21180, 21743, 21965, 22049, 22203, 22343, 22450, 23906, 23957, 23983, 24503, 24554, 24592, 24779, 24806, 25032, 25042, 25091, 25111, 27991, 28060, 28093, 28261, 28444, 28467, 28570, 28602, 28924, 29242, 29297, 29382, 30222, 30978]

# %%
marker = D18O2[index]
marker
# Out:
# array([-40.97, -40.43, -39.67, -37.56, -40.92, -39.41, -39.69, -43.94,
#        -40.75, -38.37, -40.45, -42.41, -43.23, -41.08, -43.18, -41.41,
#        -40.95, -43.15, -44.29, -43.65, -41.41, -41.7 , -37.81, -42.23,
#        -42.59, -40.81, -39.52, -40.35, -43.11, -39.9 , -40.66, -42.11,
#        -42.67, -41.1 , -40.54, -40.06, -43.28, -41.79, -42.47, -39.88,
#        -41.46, -40.91, -40.61, -41.33, -44.05, -39.15, -41.71, -41.7 ,
#        -40.81, -40.93, -42.13, -41.97, -39.93, -40.29, -41.94, -40.16,
#        -42.39, -38.39, -39.81, -39.36, -41.54, -43.14, -42.31, -42.59,
#        -40.25, -44.82, -40.08, -40.86, -46.02, -43.75, -42.36, -41.7 ,
#        -42.51, -42.52, -42.46, -39.06, -40.16, -40.  , -43.34, -39.39,
#        -38.45, -39.89, -41.21, -39.16, -39.75, -40.94, -39.56, -40.37,
#        -39.11, -38.56, -39.52, -39.76, -39.1 , -38.06, -39.95, -38.31,
#        -37.59, -38.65, -39.95, -37.96, -36.54, -37.18, -37.78, -37.53,
#        -39.96, -38.95, -38.79, -36.8 , -36.6 ])

# %% [markdown]
# ```
# Define
# ```

# %%
x_ts = age      # x time series
y_ts = D18O2     # y time series
x_ts_name = 'Age(Years)'
y_ts_name = r'$\delta^{18}$O'
x_marker = xpoints
y_marker = marker
plot_title = 'Oxigen 18 from Ice Core Data'

# %% [markdown]
# ```
# Plot
# ```

# %%
plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)
plt.rc('axes', labelsize=28)
plt.rc('axes', titlesize=28)
plt.rc('legend', fontsize=25)
plt.rc('lines', linewidth=0.4)

plt.rc('savefig', dpi = 300)
plt.rc('legend', title_fontsize = 25)
plt.rc('legend', facecolor = 'inherit')

font = {'family' : 'sans-serif'}#,'size'   : 25}
plt.rc('font', **font)
plt.rc('text', usetex=True)
rc('text.latex')#, preamble=r'\usepackage{fontenc}')
rc('font',**{'family':'serif','sans-serif':['Computer Modern Roman']})

# %%
style.available
# style.use('seaborn-poster') #sets the size of the charts
style.use('ggplot')

# %%
fig = go.Figure()
fig.add_trace(go.Scatter( x=x_ts, y=y_ts, name=y_ts_name,
                         line_color='deepskyblue'))

fig.add_trace(go.Scatter( x=x_marker, y=y_marker,  mode='markers', marker_color='blue', marker_symbol='cross')) # https://plotly.com/python/line-and-scatter/ 

fig.update_yaxes(title_text=y_ts_name)
fig.update_xaxes(title_text=x_ts_name)

fig.update_layout(title_text=plot_title,
                  xaxis_rangeslider_visible=True)
fig.show()
# Out:
# <div>                            <div id="2de0b5f9-25ac-4525-90ba-9983e4fa380d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2de0b5f9-25ac-4525-90ba-9983e4fa380d")) {                    Plotly.newPlot(                        "2de0b5f9-25ac-4525-90ba-9983e4fa380d",                        [{"line":{"color":"deepskyblue"},"name":"$\\delta^{18}$O","x":[11690.949152542375,11691.661971830985,11692.742857142855,11694.0,11695.435897435898,11696.7,11698.81481481481,11700.292307692307,11701.142857142862,11703.07317073171,11704.399999999998,11705.914285714282,11707.130434782606,11708.731707317074,11710.411764705885,11712.166666666664,11714.45833333333,11716.148148148144,11717.964285714286,11720.34375,11722.26086956522,11723.804878048779,11724.807692307691,11726.0,11728.163265306122,11729.209302325582,11730.363636363634,11731.6875,11733.348837209303,11734.628571428571,11736.857142857147,11738.303030303028,11739.55102040816,11740.666666666668,11742.548387096776,11744.68,11746.269230769229,11747.479999999996,11749.11428571429,11750.612903225807,11752.277777777777,11753.685714285713,11755.12195121951,11756.400000000003,11758.074074074073,11759.641025641029,11761.5,11762.780487804877,11764.386363636366,11765.851851851856,11767.302325581395,11769.062499999998,11770.897435897432,11772.869565217394,11774.344827586207,11775.911764705885,11778.166666666662,11780.166666666662,11781.806451612907,11783.695652173912,11785.536585365853,11786.815789473683,11788.10714285714,11789.961538461539,11792.043478260868,11794.093749999998,11795.488372093023,11797.038461538461,11798.806451612907,11800.545454545458,11802.192307692309,11803.228571428572,11804.4693877551,11805.923076923078,11807.629629629631,11809.423076923074,11811.47619047619,11813.470588235292,11815.07692307693,11816.764705882353,11818.586206896554,11819.808510638297,11821.703703703703,11823.093023255817,11824.5,11826.022222222222,11827.16216216216,11828.63333333333,11830.411764705885,11833.076923076922,11835.227272727276,11837.079999999998,11838.562499999996,11839.517857142859,11840.766666666666,11842.86206896552,11844.722222222223,11846.06896551724,11847.676470588238,11849.142857142862,11850.742857142857,11852.333333333334,11854.23809523809,11856.166666666668,11857.740740740739,11859.900000000001,11861.562499999998,11862.972972972968,11864.93103448276,11866.789473684215,11868.56666666667,11870.599999999999,11872.551724137926,11874.142857142859,11875.325581395351,11876.954545454546,11879.352941176467,11881.384615384613,11883.371428571432,11885.037037037036,11886.88888888889,11889.947368421053,11891.916666666659,11893.0,11894.714285714284,11896.551724137933,11898.310344827587,11900.0,11901.86206896552,11903.38235294118,11905.119999999997,11907.192307692305,11908.906249999996,11910.653846153846,11912.297297297297,11914.230769230771,11915.714285714286,11917.359999999999,11918.971428571429,11920.526315789473,11921.820512820512,11923.153846153844,11925.111111111108,11926.642857142857,11928.478260869566,11930.44,11932.639999999998,11934.55,11936.348837209303,11937.6875,11939.035714285714,11940.74193548387,11942.65217391304,11944.81481481482,11946.375000000004,11947.5,11948.862068965513,11950.599999999997,11952.142857142862,11953.962962962964,11955.600000000002,11956.92682926829,11958.333333333332,11959.956521739132,11961.583333333336,11963.57894736842,11965.545454545454,11967.03125,11968.67857142857,11970.54054054054,11971.785714285714,11973.245283018867,11974.294117647058,11976.294117647065,11978.600000000002,11980.347826086956,11982.583333333332,11984.0,11985.925925925927,11987.437500000002,11989.05,11991.478260869566,11993.531249999996,11994.85365853659,11996.48,11998.461538461539,12000.239999999996,12002.0,12003.960000000001,12005.884615384619,12007.48648648648 ...
