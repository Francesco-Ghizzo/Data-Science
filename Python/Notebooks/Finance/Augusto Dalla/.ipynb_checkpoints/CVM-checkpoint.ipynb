# %%
import pandas as pd
import numpy as np

# %%
d = pd.read_csv(r'dfp_cia_aberta_BPA_con_2020.csv', encoding = 'ISO-8859-1', sep=";")    # leio o .csv

# %%
d
# Out:
#                  CNPJ_CIA    DT_REFER  VERSAO        DENOM_CIA  CD_CVM  \
# 0      00.000.000/0001-91  2020-12-31       2  BCO BRASIL S.A.    1023
# 1      00.000.000/0001-91  2020-12-31       2  BCO BRASIL S.A.    1023
# 2      00.000.000/0001-91  2020-12-31       2  BCO BRASIL S.A.    1023
# 3      00.000.000/0001-91  2020-12-31       2  BCO BRASIL S.A.    1023
# 4      00.000.000/0001-91  2020-12-31       2  BCO BRASIL S.A.    1023
# ...                   ...         ...     ...              ...     ...
# 56792  97.837.181/0001-47  2020-12-31       1       DEXCO S.A.   21091
# 56793  97.837.181/0001-47  2020-12-31       1       DEXCO S.A.   21091
# 56794  97.837.181/0001-47  2020-12-31       1       DEXCO S.A.   21091
# 56795  97.837.181/0001-47  2020-12-31       1       DEXCO S.A.   21091
# 56796  97.837.181/0001-47  2020-12-31       1       DEXCO S.A.   21091
#
#                                         GRUPO_DFP MOEDA ESCALA_MOEDA  \
# 0      DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL
# 1      DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL
# 2      DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL
# 3      DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL
# 4      DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL
# ...                                           ...   ...          ...
# 56792  DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL
# 56793  DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL
# 56794  DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL
# 56795  DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL
# 56796  DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL
#
#       ORDEM_EXERC DT_FIM_EXERC       CD_CONTA  \
# 0       PENÚLTIMO   2019-12-31              1
# 1          ÚLTIMO   2020-12-31              1
# 2       PENÚLTIMO   2019-12-31           1.01
# 3          ÚLTIMO   2020-12-31           1.01
# 4       PENÚLTIMO   2019-12-31        1.01.01
# ...           ...          ...            ...
# 56792      ÚLTIMO   2020-12-31  1.02.04.02.09
# 56793   PENÚLTIMO   2019-12-31  1.02.04.02.10
# 56794      ÚLTIMO   2020-12-31  1.02.04.02.10
# 56795   PENÚLTIMO   2019-12-31  1.02.04.02.11
# 56796      ÚLTIMO   2020-12-31  1.02.04.02.11
#
#                                                 DS_CONTA      VL_CONTA  \
# 0                                            Ativo Total  1.452267e+09
# 1                                            Ativo Total  1.693794e+09
# 2                          Caixa e Equivalentes de Caixa  7.193602e+07
# 3                          Caixa e Equivalentes de Caixa  1.761895e+08
# 4                                                  Caixa  1.417119e+07
# ...                                                  ...           ...
# 56792  Goodwill na aquisição da Massima Revestimentos...  6.110000e+03
# 56793  Goodwill na aquisição da Cecrisa Revestimentos...  1.630000e+05
# 56794  Goodwill na aquisição da Cecrisa Revestimentos...  1.684300e+05
# 56795                               Goodwill Viva Decora  0.000000e+00
# 56796                               Goodwill Viva Decora  0.000000e+00
#
#       ST_CONTA_FIXA
# 0                 S
# 1                 S
# 2                 S
# 3                 S
# 4                 S
# ...             ...
# 56792             N
# 56793             N
# 56794             N
# 56795             N
# 56796             N
#
# [56797 rows x 14 columns]

# %%
d = d[d['CNPJ_CIA'] == '97.837.181/0001-47']    # dataframe = linhas do dataframe onde ('CNPJ_CIA' == '97.837.181/0001-47') == True
                                                # (seleciono somente as linhas relativas a uma companhia de interesse)

# %%
d
# Out:
#                  CNPJ_CIA    DT_REFER  VERSAO   DENOM_CIA  CD_CVM  \
# 56645  97.837.181/0001-47  2020-12-31       1  DEXCO S.A.   21091
# 56646  97.837.181/0001-47  2020-12-31       1  DEXCO S.A.   21091
# 56647  97.837.181/0001-47  2020-12-31       1  DEXCO S.A.   21091
# 56648  97.837.181/0001-47  2020-12-31       1  DEXCO S.A.   21091
# 56649  97.837.181/0001-47  2020-12-31       1  DEXCO S.A.   21091
# ...                   ...         ...     ...         ...     ...
# 56792  97.837.181/0001-47  2020-12-31       1  DEXCO S.A.   21091
# 56793  97.837.181/0001-47  2020-12-31       1  DEXCO S.A.   21091
# 56794  97.837.181/0001-47  2020-12-31       1  DEXCO S.A.   21091
# 56795  97.837.181/0001-47  2020-12-31       1  DEXCO S.A.   21091
# 56796  97.837.181/0001-47  2020-12-31       1  DEXCO S.A.   21091
#
#                                         GRUPO_DFP MOEDA ESCALA_MOEDA  \
# 56645  DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL
# 56646  DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL
# 56647  DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL
# 56648  DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL
# 56649  DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL
# ...                                           ...   ...          ...
# 56792  DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL
# 56793  DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL
# 56794  DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL
# 56795  DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL
# 56796  DF Consolidado - Balanço Patrimonial Ativo  REAL          MIL
#
#       ORDEM_EXERC DT_FIM_EXERC       CD_CONTA  \
# 56645   PENÚLTIMO   2019-12-31              1
# 56646      ÚLTIMO   2020-12-31              1
# 56647   PENÚLTIMO   2019-12-31           1.01
# 56648      ÚLTIMO   2020-12-31           1.01
# 56649   PENÚLTIMO   2019-12-31        1.01.01
# ...           ...          ...            ...
# 56792      ÚLTIMO   2020-12-31  1.02.04.02.09
# 56793   PENÚLTIMO   2019-12-31  1.02.04.02.10
# 56794      ÚLTIMO   2020-12-31  1.02.04.02.10
# 56795   PENÚLTIMO   2019-12-31  1.02.04.02.11
# 56796      ÚLTIMO   2020-12-31  1.02.04.02.11
#
#                                                 DS_CONTA    VL_CONTA  \
# 56645                                        Ativo Total  10714688.0
# 56646                                        Ativo Total  11498520.0
# 56647                                   Ativo Circulante   3514047.0
# 56648                                   Ativo Circulante   4220022.0
# 56649                      Caixa e Equivalentes de Caixa   1243223.0
# ...                                                  ...         ...
# 56792  Goodwill na aquisição da Massima Revestimentos...      6110.0
# 56793  Goodwill na aquisição da Cecrisa Revestimentos...    163000.0
# 56794  Goodwill na aquisição da Cecrisa Revestimentos...    168430.0
# 56795                               Goodwill Viva Decora         0.0
# 56796                               Goodwill Viva Decora         0.0
#
#       ST_CONTA_FIXA
# 56645             S
# 56646             S
# 56647             S
# 56648             S
# 56649             S
# ...             ...
# 56792             N
# 56793             N
# 56794             N
# 56795             N
# 56796             N
#
# [152 rows x 14 columns]

# %%
df = d[['ORDEM_EXERC','CD_CONTA','DS_CONTA','VL_CONTA']].copy()

# %%
df
# Out:
#       ORDEM_EXERC       CD_CONTA  \
# 56645   PENÚLTIMO              1
# 56646      ÚLTIMO              1
# 56647   PENÚLTIMO           1.01
# 56648      ÚLTIMO           1.01
# 56649   PENÚLTIMO        1.01.01
# ...           ...            ...
# 56792      ÚLTIMO  1.02.04.02.09
# 56793   PENÚLTIMO  1.02.04.02.10
# 56794      ÚLTIMO  1.02.04.02.10
# 56795   PENÚLTIMO  1.02.04.02.11
# 56796      ÚLTIMO  1.02.04.02.11
#
#                                                 DS_CONTA    VL_CONTA
# 56645                                        Ativo Total  10714688.0
# 56646                                        Ativo Total  11498520.0
# 56647                                   Ativo Circulante   3514047.0
# 56648                                   Ativo Circulante   4220022.0
# 56649                      Caixa e Equivalentes de Caixa   1243223.0
# ...                                                  ...         ...
# 56792  Goodwill na aquisição da Massima Revestimentos...      6110.0
# 56793  Goodwill na aquisição da Cecrisa Revestimentos...    163000.0
# 56794  Goodwill na aquisição da Cecrisa Revestimentos...    168430.0
# 56795                               Goodwill Viva Decora         0.0
# 56796                               Goodwill Viva Decora         0.0
#
# [152 rows x 4 columns]

# %%
df.drop_duplicates(['CD_CONTA','DS_CONTA'], inplace = True)

# %%
df
# Out:
#       ORDEM_EXERC       CD_CONTA  \
# 56645   PENÚLTIMO              1
# 56647   PENÚLTIMO           1.01
# 56649   PENÚLTIMO        1.01.01
# 56651   PENÚLTIMO        1.01.02
# 56653   PENÚLTIMO     1.01.02.01
# ...           ...            ...
# 56787   PENÚLTIMO  1.02.04.02.07
# 56789   PENÚLTIMO  1.02.04.02.08
# 56791   PENÚLTIMO  1.02.04.02.09
# 56793   PENÚLTIMO  1.02.04.02.10
# 56795   PENÚLTIMO  1.02.04.02.11
#
#                                                 DS_CONTA    VL_CONTA
# 56645                                        Ativo Total  10714688.0
# 56647                                   Ativo Circulante   3514047.0
# 56649                      Caixa e Equivalentes de Caixa   1243223.0
# 56651                             Aplicações Financeiras         0.0
# 56653  Aplicações Financeiras Avaliadas a Valor Justo...         0.0
# ...                                                  ...         ...
# 56787          Goodwill na aquisição da Caetex Florestal      8767.0
# 56789  Goodwill na aquisição da Cerâmica Urussanga em...     92944.0
# 56791  Goodwill na aquisição da Massima Revestimentos...      6110.0
# 56793  Goodwill na aquisição da Cecrisa Revestimentos...    163000.0
# 56795                               Goodwill Viva Decora         0.0
#
# [76 rows x 4 columns]

# %%
rubricas = {a:b for a,b in zip(d['CD_CONTA'],d['DS_CONTA'])}    # crio um dicionário chamado "rubricas" com os elementos de 'CD_CONTA' como keys e os elementos de 'DS_CONTA'como values

# %%
rubricas
# Out:
# {'1': 'Ativo Total',
#  '1.01': 'Ativo Circulante',
#  '1.01.01': 'Caixa e Equivalentes de Caixa',
#  '1.01.02': 'Aplicações Financeiras',
#  '1.01.02.01': 'Aplicações Financeiras Avaliadas a Valor Justo através do Resultado',
#  '1.01.02.01.01': 'Títulos para Negociação',
#  '1.01.02.01.02': 'Títulos Designados a Valor Justo',
#  '1.01.02.02': 'Aplicações Financeiras Avaliadas a Valor Justo através de Outros Resultados Abrangentes',
#  '1.01.02.03': 'Aplicações Financeiras Avaliadas ao Custo Amortizado',
#  '1.01.03': 'Contas a Receber',
#  '1.01.03.01': 'Clientes',
#  '1.01.03.01.01': 'Contas a receber de clientes',
#  '1.01.03.01.02': 'Contas a receber de partes relacionadas',
#  '1.01.03.02': 'Outras Contas a Receber',
#  '1.01.03.02.01': 'Valores a receber',
#  '1.01.04': 'Estoques',
#  '1.01.05': 'Ativos Biológicos',
#  '1.01.06': 'Tributos a Recuperar',
#  '1.01.06.01': 'Tributos Correntes a Recuperar',
#  '1.01.07': 'Despesas Antecipadas',
#  '1.01.08': 'Outros Ativos Circulantes',
#  '1.01.08.01': 'Ativos Não-Correntes a Venda',
#  '1.01.08.02': 'Ativos de Operações Descontinuadas',
#  '1.01.08.03': 'Outros',
#  '1.02': 'Ativo Não Circulante',
#  '1.02.01': 'Ativo Realizável a Longo Prazo',
#  '1.02.01.01': 'Aplicações Financeiras Avaliadas a Valor Justo através do Resultado',
#  '1.02.01.01.01': 'Títulos Designados a Valor Justo',
#  '1.02.01.02': 'Aplicações Financeiras Avaliadas a Valor Justo através de Outros Resultados Abrangentes',
#  '1.02.01.03': 'Aplicações Financeiras Avaliadas ao Custo Amortizado',
#  '1.02.01.04': 'Contas a Receber',
#  '1.02.01.04.01': 'Clientes',
#  '1.02.01.04.02': 'Outras Contas a Receber',
#  '1.02.01.05': 'Estoques',
#  '1.02.01.06': 'Ativos Biológicos',
#  '1.02.01.07': 'Tributos Diferidos',
#  '1.02.01.07.01': 'Imposto de Renda e Contribuição Social Diferidos',
#  '1.02.01.08': 'Despesas Antecipadas',
#  '1.02.01.09': 'Créditos com Partes Relacionadas',
#  '1.02.01.09.01': 'Créditos com Coligadas',
#  '1.02.01.09.03': 'Créditos com Controladores',
#  '1.02.01.09.04': 'Créditos com Outras Partes Relacionadas',
#  '1.02.01.10': 'Outros Ativos Não Circulantes',
#  '1.02.01.10.01': 'Ativos Não-Correntes a Venda',
#  '1.02.01.10.02': 'Ativos de Operações Descontinuadas',
#  '1.02.01.10.03': 'Depósitos vinculados',
#  '1.02.01.10.04': 'Créditos com plano de previdência',
#  '1.02.01.10.05': 'Impostos e contribuições a recuperar',
#  '1.02.01.10.06': 'Ativos de direito de uso',
#  '1.02.02': 'Investimentos',
#  '1.02.02.01': 'Participações Societárias',
#  '1.02.02.01.01': 'Participações em Coligadas',
#  '1.02.02.01.04': 'Participações em Controladas em Conjunto',
#  '1.02.02.01.05': 'Outros Investimentos',
#  '1.02.02.02': 'Propriedades para Investimento',
#  '1.02.03': 'Imobilizado',
#  '1.02.03.01': 'Imobilizado em Operação',
#  '1.02.03.02': 'Direito de Uso em Arrendamento',
#  '1.02.03.03': 'Imobilizado em Andamento',
#  '1.02.04': 'Intangível',
#  '1.02.04.01': 'Intangíveis',
#  '1.02.04.01.01': 'Contrato de Concessão',
#  '1.02.04.01.02': 'Carteira de Clientes',
#  '1.02.04.01.03': 'Softwares, marcas e patentes',
#  '1.02.04.02': 'Goodwill',
#  '1.02.04.02.01': 'Goodwill na aquisição da Satipel em 2009',
#  '1.02.04.02.02': 'Goodwill na aquisição Cerâmica Monte Carlo em 2008',
#  '1.02.04.02.03': 'Goodwill na aquisição da Deca Nordeste em 2011',
#  '1.02.04.02.04': 'Goodwill na aquisição da Ind. Metalúrgica Jacareí em 2012',
#  '1.02.04.02.05': 'Goodwill na aquisição da Thermosystem em 2013',
#  '1.02.04.02.06': 'Goodwill na aquisição da DuchaCorona em 2015',
#  '1.02.04.02.07': 'Goodwill na aquisição da Caetex Florestal',
#  '1.02.04.02.08': 'Goodwill na aquisição da Cerâmica Urussanga em 2017',
#  '1.02.04.02.09': 'Goodwill na aquisição da Massima Revestimentos em 2017',
#  '1.02.04.02.10': 'Goodwill na aquisição da Cecrisa Revestimentos em 2019',
#  '1.02.04.02.11': 'Goodwill Viva Decora'}

# %%
def primeiro_filtro(código):    # a variável código é um key do dicionário (elemento da coluna 'CD_CONTA')
    if len(código) == 1:    # se o tamanho do código é igual a 1
        classificação = rubricas[código]    # a variável classificação é igual à Descrição da Conta que corresponde à chave "código" de tamanho 1
    elif len(código) > 1:   # se o tamanho do código for maior do que 1
        classificação = rubricas[código[:1]]    # a variável classificação é igual à Descrição da Conta que corresponde ao primeiro algarismo da chave "código"
    return classificação

df['1º Classificação'] = df['CD_CONTA'].map(lambda x:primeiro_filtro(x))

# %%
df
# Out:
#       ORDEM_EXERC       CD_CONTA  \
# 56645   PENÚLTIMO              1
# 56647   PENÚLTIMO           1.01
# 56649   PENÚLTIMO        1.01.01
# 56651   PENÚLTIMO        1.01.02
# 56653   PENÚLTIMO     1.01.02.01
# ...           ...            ...
# 56787   PENÚLTIMO  1.02.04.02.07
# 56789   PENÚLTIMO  1.02.04.02.08
# 56791   PENÚLTIMO  1.02.04.02.09
# 56793   PENÚLTIMO  1.02.04.02.10
# 56795   PENÚLTIMO  1.02.04.02.11
#
#                                                 DS_CONTA    VL_CONTA  \
# 56645                                        Ativo Total  10714688.0
# 56647                                   Ativo Circulante   3514047.0
# 56649                      Caixa e Equivalentes de Caixa   1243223.0
# 56651                             Aplicações Financeiras         0.0
# 56653  Aplicações Financeiras Avaliadas a Valor Justo...         0.0
# ...                                                  ...         ...
# 56787          Goodwill na aquisição da Caetex Florestal      8767.0
# 56789  Goodwill na aquisição da Cerâmica Urussanga em...     92944.0
# 56791  Goodwill na aquisição da Massima Revestimentos...      6110.0
# 56793  Goodwill na aquisição da Cecrisa Revestimentos...    163000.0
# 56795                               Goodwill Viva Decora         0.0
#
#       1º Classificação
# 56645      Ativo Total
# 56647      Ativo Total
# 56649      Ativo Total
# 56651      Ativo Total
# 56653      Ativo Total
# ...                ...
# 56787      Ativo Total
# 56789      Ativo Total
# 56791      Ativo Total
# 56793      Ativo Total
# 56795      Ativo Total
#
# [76 rows x 5 columns]

# %%
def segundo_filtro(código):
    if len(código) == 4:
        classificação = rubricas[código]
    elif len(código) > 4:
        classificação = rubricas[código[:4]]
    elif len(código) < 4:
        classificação = rubricas[código]
    return classificação

df['2º Classificação'] = df['CD_CONTA'].map(lambda x:segundo_filtro(x))

# %%
df
# Out:
#       ORDEM_EXERC       CD_CONTA  \
# 56645   PENÚLTIMO              1
# 56647   PENÚLTIMO           1.01
# 56649   PENÚLTIMO        1.01.01
# 56651   PENÚLTIMO        1.01.02
# 56653   PENÚLTIMO     1.01.02.01
# ...           ...            ...
# 56787   PENÚLTIMO  1.02.04.02.07
# 56789   PENÚLTIMO  1.02.04.02.08
# 56791   PENÚLTIMO  1.02.04.02.09
# 56793   PENÚLTIMO  1.02.04.02.10
# 56795   PENÚLTIMO  1.02.04.02.11
#
#                                                 DS_CONTA    VL_CONTA  \
# 56645                                        Ativo Total  10714688.0
# 56647                                   Ativo Circulante   3514047.0
# 56649                      Caixa e Equivalentes de Caixa   1243223.0
# 56651                             Aplicações Financeiras         0.0
# 56653  Aplicações Financeiras Avaliadas a Valor Justo...         0.0
# ...                                                  ...         ...
# 56787          Goodwill na aquisição da Caetex Florestal      8767.0
# 56789  Goodwill na aquisição da Cerâmica Urussanga em...     92944.0
# 56791  Goodwill na aquisição da Massima Revestimentos...      6110.0
# 56793  Goodwill na aquisição da Cecrisa Revestimentos...    163000.0
# 56795                               Goodwill Viva Decora         0.0
#
#       1º Classificação      2º Classificação
# 56645      Ativo Total           Ativo Total
# 56647      Ativo Total      Ativo Circulante
# 56649      Ativo Total      Ativo Circulante
# 56651      Ativo Total      Ativo Circulante
# 56653      Ativo Total      Ativo Circulante
# ...                ...                   ...
# 56787      Ativo Total  Ativo Não Circulante
# 56789      Ativo Total  Ativo Não Circulante
# 56791      Ativo Total  Ativo Não Circulante
# 56793      Ativo Total  Ativo Não Circulante
# 56795      Ativo Total  Ativo Não Circulante
#
# [76 rows x 6 columns]

# %%
def terceiro_filtro(código):
    if len(código) == 7:
        classificação = rubricas[código]
    elif len(código) > 7:
        classificação = rubricas[código[:7]]
    elif len(código) < 7:
        classificação = rubricas[código]
    return classificação

df['3º Classificação'] = df['CD_CONTA'].map(lambda x:terceiro_filtro(x))

# %%
df
# Out:
#       ORDEM_EXERC       CD_CONTA  \
# 56645   PENÚLTIMO              1
# 56647   PENÚLTIMO           1.01
# 56649   PENÚLTIMO        1.01.01
# 56651   PENÚLTIMO        1.01.02
# 56653   PENÚLTIMO     1.01.02.01
# ...           ...            ...
# 56787   PENÚLTIMO  1.02.04.02.07
# 56789   PENÚLTIMO  1.02.04.02.08
# 56791   PENÚLTIMO  1.02.04.02.09
# 56793   PENÚLTIMO  1.02.04.02.10
# 56795   PENÚLTIMO  1.02.04.02.11
#
#                                                 DS_CONTA    VL_CONTA  \
# 56645                                        Ativo Total  10714688.0
# 56647                                   Ativo Circulante   3514047.0
# 56649                      Caixa e Equivalentes de Caixa   1243223.0
# 56651                             Aplicações Financeiras         0.0
# 56653  Aplicações Financeiras Avaliadas a Valor Justo...         0.0
# ...                                                  ...         ...
# 56787          Goodwill na aquisição da Caetex Florestal      8767.0
# 56789  Goodwill na aquisição da Cerâmica Urussanga em...     92944.0
# 56791  Goodwill na aquisição da Massima Revestimentos...      6110.0
# 56793  Goodwill na aquisição da Cecrisa Revestimentos...    163000.0
# 56795                               Goodwill Viva Decora         0.0
#
#       1º Classificação      2º Classificação               3º Classificação
# 56645      Ativo Total           Ativo Total                    Ativo Total
# 56647      Ativo Total      Ativo Circulante               Ativo Circulante
# 56649      Ativo Total      Ativo Circulante  Caixa e Equivalentes de Caixa
# 56651      Ativo Total      Ativo Circulante         Aplicações Financeiras
# 56653      Ativo Total      Ativo Circulante         Aplicações Financeiras
# ...                ...                   ...                            ...
# 56787      Ativo Total  Ativo Não Circulante                     Intangível
# 56789      Ativo Total  Ativo Não Circulante                     Intangível
# 56791      Ativo Total  Ativo Não Circulante                     Intangível
# 56793      Ativo Total  Ativo Não Circulante                     Intangível
# 56795      Ativo Total  Ativo Não Circulante                     Intangível
#
# [76 rows x 7 columns]

# %%
def quarto_filtro(código):
    if len(código) == 10:
        classificação = rubricas[código]
    elif len(código) > 10:
        classificação = rubricas[código[:10]]
    elif len(código) < 10:
        classificação = rubricas[código]
    return classificação

df['4º Classificação'] = df['CD_CONTA'].map(lambda x:quarto_filtro(x))

# %%
df
# Out:
#       ORDEM_EXERC       CD_CONTA  \
# 56645   PENÚLTIMO              1
# 56647   PENÚLTIMO           1.01
# 56649   PENÚLTIMO        1.01.01
# 56651   PENÚLTIMO        1.01.02
# 56653   PENÚLTIMO     1.01.02.01
# ...           ...            ...
# 56787   PENÚLTIMO  1.02.04.02.07
# 56789   PENÚLTIMO  1.02.04.02.08
# 56791   PENÚLTIMO  1.02.04.02.09
# 56793   PENÚLTIMO  1.02.04.02.10
# 56795   PENÚLTIMO  1.02.04.02.11
#
#                                                 DS_CONTA    VL_CONTA  \
# 56645                                        Ativo Total  10714688.0
# 56647                                   Ativo Circulante   3514047.0
# 56649                      Caixa e Equivalentes de Caixa   1243223.0
# 56651                             Aplicações Financeiras         0.0
# 56653  Aplicações Financeiras Avaliadas a Valor Justo...         0.0
# ...                                                  ...         ...
# 56787          Goodwill na aquisição da Caetex Florestal      8767.0
# 56789  Goodwill na aquisição da Cerâmica Urussanga em...     92944.0
# 56791  Goodwill na aquisição da Massima Revestimentos...      6110.0
# 56793  Goodwill na aquisição da Cecrisa Revestimentos...    163000.0
# 56795                               Goodwill Viva Decora         0.0
#
#       1º Classificação      2º Classificação               3º Classificação  \
# 56645      Ativo Total           Ativo Total                    Ativo Total
# 56647      Ativo Total      Ativo Circulante               Ativo Circulante
# 56649      Ativo Total      Ativo Circulante  Caixa e Equivalentes de Caixa
# 56651      Ativo Total      Ativo Circulante         Aplicações Financeiras
# 56653      Ativo Total      Ativo Circulante         Aplicações Financeiras
# ...                ...                   ...                            ...
# 56787      Ativo Total  Ativo Não Circulante                     Intangível
# 56789      Ativo Total  Ativo Não Circulante                     Intangível
# 56791      Ativo Total  Ativo Não Circulante                     Intangível
# 56793      Ativo Total  Ativo Não Circulante                     Intangível
# 56795      Ativo Total  Ativo Não Circulante                     Intangível
#
#                                         4º Classificação
# 56645                                        Ativo Total
# 56647                                   Ativo Circulante
# 56649                      Caixa e Equivalentes de Caixa
# 56651                             Aplicações Financeiras
# 56653  Aplicações Financeiras Avaliadas a Valor Justo...
# ...                                                  ...
# 56787                                           Goodwill
# 56789                                           Goodwill
# 56791                                           Goodwill
# 56793                                           Goodwill
# 56795                                           Goodwill
#
# [76 rows x 8 columns]

# %%
def quinto_filtro(código):
    if len(código) == 13:
        classificação = rubricas[código]
    elif len(código) > 13:
        classificação = rubricas[código[:13]]
    elif len(código) < 13:
        classificação = rubricas[código]
    return classificação

df['5º Classificação'] = df['CD_CONTA'].map(lambda x:quinto_filtro(x))

# %%
df
# Out:
#       ORDEM_EXERC       CD_CONTA  \
# 56645   PENÚLTIMO              1
# 56647   PENÚLTIMO           1.01
# 56649   PENÚLTIMO        1.01.01
# 56651   PENÚLTIMO        1.01.02
# 56653   PENÚLTIMO     1.01.02.01
# ...           ...            ...
# 56787   PENÚLTIMO  1.02.04.02.07
# 56789   PENÚLTIMO  1.02.04.02.08
# 56791   PENÚLTIMO  1.02.04.02.09
# 56793   PENÚLTIMO  1.02.04.02.10
# 56795   PENÚLTIMO  1.02.04.02.11
#
#                                                 DS_CONTA    VL_CONTA  \
# 56645                                        Ativo Total  10714688.0
# 56647                                   Ativo Circulante   3514047.0
# 56649                      Caixa e Equivalentes de Caixa   1243223.0
# 56651                             Aplicações Financeiras         0.0
# 56653  Aplicações Financeiras Avaliadas a Valor Justo...         0.0
# ...                                                  ...         ...
# 56787          Goodwill na aquisição da Caetex Florestal      8767.0
# 56789  Goodwill na aquisição da Cerâmica Urussanga em...     92944.0
# 56791  Goodwill na aquisição da Massima Revestimentos...      6110.0
# 56793  Goodwill na aquisição da Cecrisa Revestimentos...    163000.0
# 56795                               Goodwill Viva Decora         0.0
#
#       1º Classificação      2º Classificação               3º Classificação  \
# 56645      Ativo Total           Ativo Total                    Ativo Total
# 56647      Ativo Total      Ativo Circulante               Ativo Circulante
# 56649      Ativo Total      Ativo Circulante  Caixa e Equivalentes de Caixa
# 56651      Ativo Total      Ativo Circulante         Aplicações Financeiras
# 56653      Ativo Total      Ativo Circulante         Aplicações Financeiras
# ...                ...                   ...                            ...
# 56787      Ativo Total  Ativo Não Circulante                     Intangível
# 56789      Ativo Total  Ativo Não Circulante                     Intangível
# 56791      Ativo Total  Ativo Não Circulante                     Intangível
# 56793      Ativo Total  Ativo Não Circulante                     Intangível
# 56795      Ativo Total  Ativo Não Circulante                     Intangível
#
#                                         4º Classificação  \
# 56645                                        Ativo Total
# 56647                                   Ativo Circulante
# 56649                      Caixa e Equivalentes de Caixa
# 56651                             Aplicações Financeiras
# 56653  Aplicações Financeiras Avaliadas a Valor Justo...
# ...                                                  ...
# 56787                                           Goodwill
# 56789                                           Goodwill
# 56791                                           Goodwill
# 56793                                           Goodwill
# 56795                                           Goodwill
#
#                                         5º Classificação
# 56645                                        Ativo Total
# 56647                                   Ativo Circulante
# 56649                      Caixa e Equivalentes de Caixa
# 56651                             Aplicações Financeiras
# 56653  Aplicações Financeiras Avaliadas a Valor Justo...
# ...                                                  ...
# 56787          Goodwill na aquisição da Caetex Florestal
# 56789  Goodwill na aquisição da Cerâmica Urussanga em...
# 56791  Goodwill na aquisição da Massima Revestimentos...
# 56793  Goodwill na aquisição da Cecrisa Revestimentos...
# 56795                               Goodwill Viva Decora
#
# [76 rows x 9 columns]

# %%
ultimo_df = df[(df['ORDEM_EXERC'] == 'ÚLTIMO')].copy()
ultimo_df.rename(columns = {'VL_CONTA':'Último'},inplace = True)
ultimo_df.drop('ORDEM_EXERC',axis = 1,inplace = True)
ultimo_df.reset_index(inplace = True)
penultimo_df = df[(df['ORDEM_EXERC'] == 'PENÚLTIMO')].copy()
penultimo_df.rename(columns = {'VL_CONTA':'Penúltimo'},inplace = True)
penultimo_df.drop('ORDEM_EXERC',axis = 1, inplace = True)
penultimo_df.reset_index(inplace = True)
new_df = pd.concat((ultimo_df.loc[:,(['DS_CONTA','1º Classificação','2º Classificação','3º Classificação',
                                      '4º Classificação','5º Classificação','Último'])],penultimo_df.loc[:,('Penúltimo')]),axis = 1)
