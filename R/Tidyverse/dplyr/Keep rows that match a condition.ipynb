# %% [markdown]
# <h1>Keep rows that match a condition</h1>
#
# <small>Source: <a href="https://github.com/tidyverse/dplyr/blob/pkgdown-v1.1.4/R/filter.R"><code>R/filter.R</code></a></small>
# <div><code>filter.Rd</code></div>
#
# <p>The <code>filter()</code> function is used to subset a data frame,
# retaining all rows that satisfy your conditions.
# To be retained, the row must produce a value of <code>TRUE</code> for all conditions.
# Note that when a condition evaluates to <code>NA</code> the row will be dropped, unlike base subsetting with <code>[</code>.</p>

# %% [markdown]
# # <h2 id="ref-usage">Usage</h2>
#
# <pre><code>filter(.data, ..., .by = NULL, .preserve = FALSE)</code></pre>

# %% [markdown]
# # <h2 id="arguments">Arguments</h2>
#
# <dl>
#
# <dt id="arg--data">.data</dt>
# <dd><p>A data frame, data frame extension (e.g. a tibble), or a
# lazy data frame (e.g. from dbplyr or dtplyr). See <em>Methods</em>, below, for more details.</p></dd>
#
# <dt id="arg--">...</dt>
# <dd><p>&lt;<code><a href="https://rlang.r-lib.org/reference/args_data_masking.html">data-masking</a></code>&gt; Expressions that
# return a logical value, and are defined in terms of the variables in
# <code>.data</code>. If multiple expressions are included, they are combined with the <code>&amp;</code> operator. Only rows for which all conditions evaluate to <code>TRUE</code> are kept.</p></dd>
#
# <dt id="arg--by">.by</dt>
# <dd><p>&lt;<code><a href="dplyr_tidy_select.html">tidy-select</a></code>&gt; Optionally, a selection of columns to group by for just this operation, functioning as an alternative to <code><a href="group_by.html">group_by()</a></code>. For details and examples, see <a href="dplyr_by.html">?dplyr_by</a>.</p></dd>
#
# <dt id="arg--preserve">.preserve</dt>
# <dd><p>Relevant when the <code>.data</code> input is grouped.
# If <code>.preserve = FALSE</code> (the default), the grouping structure is recalculated based on the resulting data, otherwise the grouping is kept as is.</p></dd>

# %% [markdown]
# # <h2 id="value">Value</h2>
#
# <p>An object of the same type as <code>.data</code>. The output has the following properties:</p>
#
# <ul>
# <li><p>Rows are a subset of the input, but appear in the same order.</p></li>
# <li><p>Columns are not modified.</p></li>
# <li><p>The number of groups may be reduced (if <code>.preserve</code> is not <code>TRUE</code>).</p></li>
# <li><p>Data frame attributes are preserved.</p></li>
# </ul>

# %% [markdown]
# # <h2 id="details">Details</h2>
#
# <p>The <code>filter()</code> function is used to subset the rows of
# <code>.data</code>, applying the expressions in <code>...</code> to the column values to determine which rows should be retained. It can be applied to both grouped and ungrouped data (see <code><a href="group_by.html">group_by()</a></code> and <code><a href="group_by.html">ungroup()</a></code>). However, dplyr is not yet smart enough to optimise the filtering operation on grouped datasets that do not need grouped calculations. For this reason, filtering is often considerably faster on ungrouped data.</p>

# %% [markdown]
# # <h2 id="useful-filter-functions">Useful filter functions</h2>
#
# <p>There are many functions and operators that are useful when constructing the expressions used to filter the data:</p>
#
# <ul>
# <li><p><code><a href="https://rdrr.io/r/base/Comparison.html">==</a></code>, <code>&gt;</code>, <code>&gt;=</code> etc</p></li>
# <li><p><code>&amp;</code>, <code><a href="https://rdrr.io/r/base/Logic.html">|</a></code>, <code><a href="https://rdrr.io/r/base/Logic.html">!</a></code>, <code><a href="https://rdrr.io/r/base/Logic.html">xor()</a></code></p></li>
# <li><p><code><a href="https://rdrr.io/r/base/NA.html">is.na()</a></code></p></li>
# <li><p><code><a href="https://dplyr.tidyverse.org/reference/between.html">between()</a></code>, <code><a href="https://dplyr.tidyverse.org/reference/near.html">near()</a></code></p></li>
# </ul>

# %% [markdown]
# # <h2 id="grouped-tibbles">Grouped tibbles</h2>
#
# <p>Because filtering expressions are computed within groups, they may
# yield different results on grouped tibbles. This will be the case
# as soon as an aggregating, lagging, or ranking function is involved. Compare this ungrouped filtering:</p>
#
# <pre><code></a>starwars %&gt;% filter(mass &gt; mean(mass, >na.rm = TRUE))</code></pre>
#
# <p>With the grouped equivalent:</p>
#
# <pre><code></a>starwars %&gt;% group_by(gender) %&gt;% filter(mass &gt; mean(mass, >na.rm = TRUE))</code></pre>
#
# <p>In the ungrouped version, <code>filter()</code> compares the value of <code>mass</code> in each row to the global average (taken over the whole data set), keeping only the rows with <code>mass</code> greater than this global average. In contrast, the grouped version calculates the average mass separately for each <code>gender</code> group, and keeps rows with <code>mass</code> greater than the relevant within-gender average.</p>

# %% [markdown]
# # <h2 id="methods">Methods</h2>
#
# <p>This function is a <strong>generic</strong>, which means that packages can provide implementations (methods) for other classes. See the documentation of individual methods for extra arguments and differences in behaviour.</p>
#
# <p>The following methods are currently available in loaded packages:
# dbplyr (<code><a href="https://dbplyr.tidyverse.org/reference/filter.tbl_lazy.html">tbl_lazy</a></code>), dplyr (<code>data.frame</code>, <code>ts</code>).</p>

# %% [markdown]
# # <h2 id="see-also">See also</h2>
#
# <p>Other single table verbs:
# <code><a href="https://dplyr.tidyverse.org/reference/arrange.html">arrange</a>()</code>,
# <code><a href="https://dplyr.tidyverse.org/reference/mutate.html">mutate</a>()</code>,
# <code><a href="https://dplyr.tidyverse.org/reference/reframe.html">reframe</a>()</code>,
# <code><a href="https://dplyr.tidyverse.org/reference/rename.html">rename</a>()</code>,
# <code><a href="https://dplyr.tidyverse.org/reference/select.html">select</a>()</code>,
# <code><a href="https://dplyr.tidyverse.org/reference/slice.html">slice</a>()</code>,
# <code><a href="https://dplyr.tidyverse.org/reference/summarise.html">summarise</a>()</code></p></div>

# %% [markdown]
# # <h2 id="ref-examples">Examples</h2>

# %%
library(tidyverse)

# Filtering by one criterion
filter(starwars, species == "Human")
# Out:
# ── Attaching packages ────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.5     ✔ purrr   1.1.0
# ✔ tibble  3.1.6     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.0.2     ✔ forcats 0.5.1
#
# ── Conflicts ───────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#    name                height mass  hair_color    skin_color eye_color
# 1  Luke Skywalker      172     77.0 blond         fair       blue
# 2  Darth Vader         202    136.0 none          white      yellow
# 3  Leia Organa         150     49.0 brown         light      brown
# 4  Owen Lars           178    120.0 brown, grey   light      blue
# 5  Beru Whitesun lars  165     75.0 brown         light      blue
# 6  Biggs Darklighter   183     84.0 black         light      brown
# ...

# %%
filter(starwars, mass > 1000)
# Out:
#   name                  height mass hair_color skin_color       eye_color
# 1 Jabba Desilijic Tiure 175    1358 NA         green-tan, brown orange
#   birth_year sex            gender    homeworld species
# 1 600        hermaphroditic masculine Nal Hutta Hutt
#   films                                                      vehicles starships
# 1 The Phantom Menace, Return of the Jedi, A New Hope

# %%
# Filtering by multiple criteria within a single logical expression
filter(starwars, hair_color == "none" & eye_color == "black")
# Out:
#   name       height mass hair_color skin_color       eye_color birth_year
# 1 Nien Nunb  160    68   none       grey             black     NA
# 2 Gasgano    122    NA   none       white, blue      black     NA
# 3 Kit Fisto  196    87   none       green            black     NA
# 4 Plo Koon   188    80   none       orange           black     22
# 5 Lama Su    229    88   none       grey             black     NA
# 6 Taun We    213    NA   none       grey             black     NA
# 7 Shaak Ti   178    57   none       red, blue, white black     NA
# 8 Tion Medon 206    80   none       grey             black     NA
# 9 BB8         NA    NA   none       none             black     NA
#   sex    gender    homeworld   species
# 1 male   masculine Sullust     Sullustan
# 2 male   masculine Troiken     Xexto
# 3 male   masculine Glee Anselm Nautolan
# 4 male   masculine Dorin       Kel Dor
# 5 male   masculine Kamino      Kaminoan
# 6 female feminine  Kamino      Kaminoan
# ...

# %%
filter(starwars, hair_color == "none" | eye_color == "black")
# Out:
#    name              height mass hair_color skin_color          eye_color
# 1  Darth Vader       202    136  none       white               yellow
# 2  Greedo            173     74  NA         green               black
# 3  IG-88             200    140  none       metal               red
# 4  Bossk             190    113  none       green               red
# 5  Lobot             175     79  none       light               blue
# 6  Ackbar            180     83  none       brown mottle        orange
# 7  Nien Nunb         160     68  none       grey                black
# 8  Nute Gunray       191     90  none       mottled green       red
# 9  Jar Jar Binks     196     66  none       orange              orange
# 10 Roos Tarpals      224     82  none       grey                orange
# 11 Rugor Nass        206     NA  none       green               orange
# 12 Sebulba           112     40  none       grey, red           orange
# ...

# %%
# When multiple expressions are used, they are combined using &
filter(starwars, hair_color == "none", eye_color == "black")
# Out:
#   name       height mass hair_color skin_color       eye_color birth_year
# 1 Nien Nunb  160    68   none       grey             black     NA
# 2 Gasgano    122    NA   none       white, blue      black     NA
# 3 Kit Fisto  196    87   none       green            black     NA
# 4 Plo Koon   188    80   none       orange           black     22
# 5 Lama Su    229    88   none       grey             black     NA
# 6 Taun We    213    NA   none       grey             black     NA
# 7 Shaak Ti   178    57   none       red, blue, white black     NA
# 8 Tion Medon 206    80   none       grey             black     NA
# 9 BB8         NA    NA   none       none             black     NA
#   sex    gender    homeworld   species
# 1 male   masculine Sullust     Sullustan
# 2 male   masculine Troiken     Xexto
# 3 male   masculine Glee Anselm Nautolan
# 4 male   masculine Dorin       Kel Dor
# 5 male   masculine Kamino      Kaminoan
# 6 female feminine  Kamino      Kaminoan
# ...

# %%
# The filtering operation may yield different results on grouped
# tibbles because the expressions are computed within groups.
#
# The following filters rows where `mass` is greater than the
# global average:
starwars |> filter(mass > mean(mass, na.rm = TRUE))
# Out:
#    name                  height mass hair_color  skin_color       eye_color
# 1  Darth Vader           202     136 none        white            yellow
# 2  Owen Lars             178     120 brown, grey light            blue
# 3  Chewbacca             228     112 brown       unknown          blue
# 4  Jabba Desilijic Tiure 175    1358 NA          green-tan, brown orange
# 5  Jek Tono Porkins      180     110 brown       fair             blue
# 6  IG-88                 200     140 none        metal            red
# 7  Bossk                 190     113 none        green            red
# 8  Dexter Jettster       198     102 none        brown            yellow
# 9  Grievous              216     159 none        brown, white     green, yellow
# 10 Tarfful               234     136 brown       brown            blue
#    birth_year sex            gender    homeworld  species
# 1   41.9      male           masculine Tatooine   Human
# 2   52.0      male           masculine Tatooine   Human
# ...

# %%
# Whereas this keeps rows with `mass` greater than the gender
# average:
starwars |> group_by(gender) |> filter(mass > mean(mass, na.rm = TRUE))
# Out:
#    name                  height mass   hair_color  skin_color
# 1  Darth Vader           202     136.0 none        white
# 2  Owen Lars             178     120.0 brown, grey light
# 3  Beru Whitesun lars    165      75.0 brown       light
# 4  Chewbacca             228     112.0 brown       unknown
# 5  Jabba Desilijic Tiure 175    1358.0 NA          green-tan, brown
# 6  Jek Tono Porkins      180     110.0 brown       fair
# 7  IG-88                 200     140.0 none        metal
# 8  Bossk                 190     113.0 none        green
# 9  Ayla Secura           178      55.0 none        blue
# 10 Luminara Unduli       170      56.2 black       yellow
# 11 Zam Wesell            168      55.0 blonde      fair, green, yellow
# 12 Shaak Ti              178      57.0 none        red, blue, white
# 13 Grievous              216     159.0 none        brown, white
# 14 Tarfful               234     136.0 brown       brown
# ...
