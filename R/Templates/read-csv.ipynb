# %% [markdown]
# <h1>R: read .csv</h1>

# %% [markdown]
# <h2>Using <code>read.table</code></h2>
# <p>Reads a file in table format and creates a data frame from it, with cases corresponding to lines and variables to fields in the file. This function is the principal means of reading tabular data into R.</p>
# <p>Source: <a href="https://www.rdocumentation.org/packages/utils/versions/3.6.2/topics/read.table">read.table: Data Input</a></p>

# %%
url = "https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv"
file = "titanic.csv"
input <- if(file.exists(file)) {
    file
} else {
    url
}

titanic <- read.csv(input)  # titanic is a data.frame

# %%
titanic
# Out:
#     Survived Pclass Name
# 1   0        3      Mr. Owen Harris Braund
# 2   1        1      Mrs. John Bradley (Florence Briggs Thayer) Cumings
# 3   1        3      Miss. Laina Heikkinen
# 4   1        1      Mrs. Jacques Heath (Lily May Peel) Futrelle
# 5   0        3      Mr. William Henry Allen
# 6   0        3      Mr. James Moran
# 7   0        1      Mr. Timothy J McCarthy
# 8   0        3      Master. Gosta Leonard Palsson
# 9   1        3      Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 10  1        2      Mrs. Nicholas (Adele Achem) Nasser
# 11  1        3      Miss. Marguerite Rut Sandstrom
# 12  1        1      Miss. Elizabeth Bonnell
# 13  0        3      Mr. William Henry Saundercock
# 14  0        3      Mr. Anders Johan Andersson
# 15  0        3      Miss. Hulda Amanda Adolfina Vestrom
# 16  1        2      Mrs. (Mary D Kingcome) Hewlett
# 17  0        3      Master. Eugene Rice
# 18  1        2      Mr. Charles Eugene Williams
# 19  0        3      Mrs. Julius (Emelia Maria Vandemoortele) Vander Planke
# 20  1        3      Mrs. Fatima Masselmani
# 21  0        2      Mr. Joseph J Fynney
# 22  1        2      Mr. Lawrence Beesley
# 23  1        3      Miss. Anna McGowan
# 24  1        1      Mr. William Thompson Sloper
# 25  0        3      Miss. Torborg Danira Palsson
# 26  1        3      Mrs. Carl Oscar (Selma Augusta Emilia Johansson) Asplund
# 27  0        3      Mr. Farred Chehab Emir
# 28  0        1      Mr. Charles Alexander Fortune
# 29  1        3      Miss. Ellen O'Dwyer
# 30  0        3      Mr. Lalio Todoroff
# ⋮   ⋮        ⋮      ⋮
# 858 0        2      Mr. Frederick Edward Giles
# 859 1        1      Mrs. Frederick Joel (Margaret Welles Barron) Swift
# 860 0        3      Miss. Dorothy Edith Sage
# 861 0        2      Mr. John William Gill
# 862 1        2      Mrs. (Karolina) Bystrom
# 863 1        2      Miss. Asuncion Duran y More
# 864 0        1      Mr. Washington Augustus II Roebling
# 865 0        3      Mr. Philemon van Melkebeke
# 866 1        3      Master. Harold Theodor Johnson
# 867 0        3      Mr. Cerin Balkic
# 868 1        1      Mrs. Richard Leonard (Sallie Monypeny) Beckwith
# 869 0        1      Mr. Frans Olof Carlsson
# 870 0        3      Mr. Victor Vander Cruyssen
# 871 1        2      Mrs. Samuel (Hannah Wizosky) Abelson
# 872 1        3      Miss. Adele Kiamie Najib
# 873 0        3      Mr. Alfred Ossian Gustafsson
# 874 0        3      Mr. Nedelio Petroff
# 875 0        3      Mr. Kristo Laleff
# 876 1        1      Mrs. Thomas Jr (Lily Alexenia Wilson) Potter
# 877 1        2      Mrs. William (Imanita Parrish Hall) Shelley
# 878 0        3      Mr. Johann Markun
# 879 0        3      Miss. Gerda Ulrika Dahlberg
# 880 0        2      Mr. Frederick James Banfield
# 881 0        3      Mr. Henry Jr Sutehall
# 882 0        3      Mrs. William (Margaret Norton) Rice
# 883 0        2      Rev. Juozas Montvila
# 884 1        1      Miss. Margaret Edith Graham
# 885 0        3      Miss. Catherine Helen Johnston
# 886 1        1      Mr. Karl Howell Behr
# 887 0        3      Mr. Patrick Dooley
#     Sex    Age Siblings.Spouses.Aboard Parents.Children.Aboard Fare
# 1   male   22  1                       0                         7.2500
# 2   female 38  1                       0                        71.2833
# 3   female 26  0                       0                         7.9250
# 4   female 35  1                       0                        53.1000
# 5   male   35  0                       0                         8.0500
# 6   male   27  0                       0                         8.4583
# 7   male   54  0                       0                        51.8625
# 8   male    2  3                       1                        21.0750
# 9   female 27  0                       2                        11.1333
# 10  female 14  1                       0                        30.0708
# 11  female  4  1                       1                        16.7000
# 12  female 58  0                       0                        26.5500
# 13  male   20  0                       0                         8.0500
# 14  male   39  1                       5                        31.2750
# 15  female 14  0                       0                         7.8542
# 16  female 55  0                       0                        16.0000
# 17  male    2  4                       1                        29.1250
# 18  male   23  0                       0                        13.0000
# 19  female 31  1                       0                        18.0000
# 20  female 22  0                       0                         7.2250
# 21  male   35  0                       0                        26.0000
# 22  male   34  0                       0                        13.0000
# 23  female 15  0                       0                         8.0292
# 24  male   28  0                       0                        35.5000
# 25  female  8  3                       1                        21.0750
# 26  female 38  1                       5                        31.3875
# 27  male   26  0                       0                         7.2250
# 28  male   19  3                       2                       263.0000
# 29  female 24  0                       0                         7.8792
# 30  male   23  0                       0                         7.8958
# ⋮   ⋮      ⋮   ⋮                       ⋮                       ⋮
# 858 male   21  1                       0                       11.5000
# 859 female 48  0                       0                       25.9292
# 860 female 14  8                       2                       69.5500
# 861 male   24  0                       0                       13.0000
# 862 female 42  0                       0                       13.0000
# 863 female 27  1                       0                       13.8583
# 864 male   31  0                       0                       50.4958
# 865 male   23  0                       0                        9.5000
# 866 male    4  1                       1                       11.1333
# 867 male   26  0                       0                        7.8958
# 868 female 47  1                       1                       52.5542
# 869 male   33  0                       0                        5.0000
# 870 male   47  0                       0                        9.0000
# 871 female 28  1                       0                       24.0000
# 872 female 15  0                       0                        7.2250
# 873 male   20  0                       0                        9.8458
# 874 male   19  0                       0                        7.8958
# 875 male   23  0                       0                        7.8958
# 876 female 56  0                       1                       83.1583
# 877 female 25  0                       1                       26.0000
# 878 male   33  0                       0                        7.8958
# 879 female 22  0                       0                       10.5167
# 880 male   28  0                       0                       10.5000
# 881 male   25  0                       0                        7.0500
# 882 female 39  0                       5                       29.1250
# 883 male   27  0                       0                       13.0000
# 884 female 19  0                       0                       30.0000
# 885 female  7  1                       2                       23.4500
# 886 male   26  0                       0                       30.0000
# 887 male   32  0                       0                        7.7500

# %% [markdown]
# <h2>Using <code>readr</code></h2>
# <p><code>read_csv()</code> and <code>read_tsv()</code> are special cases of the more general
# <code>read_delim()</code>. They're useful for reading the most common types of
# flat file data, comma separated values and tab separated values,
# respectively. <code>read_csv2()</code> uses <code>;</code> for the field separator and <code>,</code> for the
# decimal point. This format is common in some European countries.</p>
# <p>Source: <a href="https://readr.tidyverse.org/reference/read_delim.html">Read a delimited file (including CSV and TSV) into a tibble</a></p>

# %%
library(readr)

# %%
url = "https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv"
file = "titanic.csv"
input <- if(file.exists(file)) {
    file
} else {
    url
}

titanic <- read_csv(input, show_col_types = FALSE)  # titanic is a tibble

# %%
titanic
# Out:
#     Survived Pclass Name
# 1   0        3      Mr. Owen Harris Braund
# 2   1        1      Mrs. John Bradley (Florence Briggs Thayer) Cumings
# 3   1        3      Miss. Laina Heikkinen
# 4   1        1      Mrs. Jacques Heath (Lily May Peel) Futrelle
# 5   0        3      Mr. William Henry Allen
# 6   0        3      Mr. James Moran
# 7   0        1      Mr. Timothy J McCarthy
# 8   0        3      Master. Gosta Leonard Palsson
# 9   1        3      Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 10  1        2      Mrs. Nicholas (Adele Achem) Nasser
# 11  1        3      Miss. Marguerite Rut Sandstrom
# 12  1        1      Miss. Elizabeth Bonnell
# 13  0        3      Mr. William Henry Saundercock
# 14  0        3      Mr. Anders Johan Andersson
# 15  0        3      Miss. Hulda Amanda Adolfina Vestrom
# 16  1        2      Mrs. (Mary D Kingcome) Hewlett
# 17  0        3      Master. Eugene Rice
# 18  1        2      Mr. Charles Eugene Williams
# 19  0        3      Mrs. Julius (Emelia Maria Vandemoortele) Vander Planke
# 20  1        3      Mrs. Fatima Masselmani
# 21  0        2      Mr. Joseph J Fynney
# 22  1        2      Mr. Lawrence Beesley
# 23  1        3      Miss. Anna McGowan
# 24  1        1      Mr. William Thompson Sloper
# 25  0        3      Miss. Torborg Danira Palsson
# 26  1        3      Mrs. Carl Oscar (Selma Augusta Emilia Johansson) Asplund
# 27  0        3      Mr. Farred Chehab Emir
# 28  0        1      Mr. Charles Alexander Fortune
# 29  1        3      Miss. Ellen O'Dwyer
# 30  0        3      Mr. Lalio Todoroff
# ⋮   ⋮        ⋮      ⋮
# 858 0        2      Mr. Frederick Edward Giles
# 859 1        1      Mrs. Frederick Joel (Margaret Welles Barron) Swift
# 860 0        3      Miss. Dorothy Edith Sage
# 861 0        2      Mr. John William Gill
# 862 1        2      Mrs. (Karolina) Bystrom
# 863 1        2      Miss. Asuncion Duran y More
# 864 0        1      Mr. Washington Augustus II Roebling
# 865 0        3      Mr. Philemon van Melkebeke
# 866 1        3      Master. Harold Theodor Johnson
# 867 0        3      Mr. Cerin Balkic
# 868 1        1      Mrs. Richard Leonard (Sallie Monypeny) Beckwith
# 869 0        1      Mr. Frans Olof Carlsson
# 870 0        3      Mr. Victor Vander Cruyssen
# 871 1        2      Mrs. Samuel (Hannah Wizosky) Abelson
# 872 1        3      Miss. Adele Kiamie Najib
# 873 0        3      Mr. Alfred Ossian Gustafsson
# 874 0        3      Mr. Nedelio Petroff
# 875 0        3      Mr. Kristo Laleff
# 876 1        1      Mrs. Thomas Jr (Lily Alexenia Wilson) Potter
# 877 1        2      Mrs. William (Imanita Parrish Hall) Shelley
# 878 0        3      Mr. Johann Markun
# 879 0        3      Miss. Gerda Ulrika Dahlberg
# 880 0        2      Mr. Frederick James Banfield
# 881 0        3      Mr. Henry Jr Sutehall
# 882 0        3      Mrs. William (Margaret Norton) Rice
# 883 0        2      Rev. Juozas Montvila
# 884 1        1      Miss. Margaret Edith Graham
# 885 0        3      Miss. Catherine Helen Johnston
# 886 1        1      Mr. Karl Howell Behr
# 887 0        3      Mr. Patrick Dooley
#     Sex    Age Siblings/Spouses Aboard Parents/Children Aboard Fare
# 1   male   22  1                       0                         7.2500
# 2   female 38  1                       0                        71.2833
# 3   female 26  0                       0                         7.9250
# 4   female 35  1                       0                        53.1000
# 5   male   35  0                       0                         8.0500
# 6   male   27  0                       0                         8.4583
# 7   male   54  0                       0                        51.8625
# 8   male    2  3                       1                        21.0750
# 9   female 27  0                       2                        11.1333
# 10  female 14  1                       0                        30.0708
# 11  female  4  1                       1                        16.7000
# 12  female 58  0                       0                        26.5500
# 13  male   20  0                       0                         8.0500
# 14  male   39  1                       5                        31.2750
# 15  female 14  0                       0                         7.8542
# 16  female 55  0                       0                        16.0000
# 17  male    2  4                       1                        29.1250
# 18  male   23  0                       0                        13.0000
# 19  female 31  1                       0                        18.0000
# 20  female 22  0                       0                         7.2250
# 21  male   35  0                       0                        26.0000
# 22  male   34  0                       0                        13.0000
# 23  female 15  0                       0                         8.0292
# 24  male   28  0                       0                        35.5000
# 25  female  8  3                       1                        21.0750
# 26  female 38  1                       5                        31.3875
# 27  male   26  0                       0                         7.2250
# 28  male   19  3                       2                       263.0000
# 29  female 24  0                       0                         7.8792
# 30  male   23  0                       0                         7.8958
# ⋮   ⋮      ⋮   ⋮                       ⋮                       ⋮
# 858 male   21  1                       0                       11.5000
# 859 female 48  0                       0                       25.9292
# 860 female 14  8                       2                       69.5500
# 861 male   24  0                       0                       13.0000
# 862 female 42  0                       0                       13.0000
# 863 female 27  1                       0                       13.8583
# 864 male   31  0                       0                       50.4958
# 865 male   23  0                       0                        9.5000
# 866 male    4  1                       1                       11.1333
# 867 male   26  0                       0                        7.8958
# 868 female 47  1                       1                       52.5542
# 869 male   33  0                       0                        5.0000
# 870 male   47  0                       0                        9.0000
# 871 female 28  1                       0                       24.0000
# 872 female 15  0                       0                        7.2250
# 873 male   20  0                       0                        9.8458
# 874 male   19  0                       0                        7.8958
# 875 male   23  0                       0                        7.8958
# 876 female 56  0                       1                       83.1583
# 877 female 25  0                       1                       26.0000
# 878 male   33  0                       0                        7.8958
# 879 female 22  0                       0                       10.5167
# 880 male   28  0                       0                       10.5000
# 881 male   25  0                       0                        7.0500
# 882 female 39  0                       5                       29.1250
# 883 male   27  0                       0                       13.0000
# 884 female 19  0                       0                       30.0000
# 885 female  7  1                       2                       23.4500
# 886 male   26  0                       0                       30.0000
# 887 male   32  0                       0                        7.7500

# %% [markdown]
# <h2>Using <code>data.table</code></h2>
# <p><code>data.table</code> is an R package that provides <strong>an enhanced version</strong> of <code>data.frame</code>s, which are the standard data structure for storing data in <code>base</code> R.</p>
# <p>Source: <a href="https://cran.r-project.org/web/packages/data.table/vignettes/datatable-intro.html">Introduction to <code>data.table</code></a></p>

# %%
library(data.table)

# %%
url = "https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv"
file = "titanic.csv"
input <- if(file.exists(file)) {
    file
} else {
    url
}
titanic <- fread(input) # titanic is a data.table data frame

# %%
titanic
# Out:
#     CountyName FIPSNumber CountyNumber PublicHealthRegion HealthServiceRegion
# 1   Anderson    1          1            4                 4/5N
# 2   Andrews     3          2            9                 9/10
# 3   Angelina    5          3            5                 4/5N
# 4   Aransas     7          4           11                 11
# 5   Archer      9          5            2                 2/3
# 6   Armstrong  11          6            1                 1
# 7   Atascosa   13          7            8                 8
# 8   Austin     15          8            6                 6/5S
# 9   Bailey     17          9            1                 1
# 10  Bandera    19         10            8                 8
# 11  Bastrop    21         11            7                 7
# 12  Baylor     23         12            2                 2/3
# 13  Bee        25         13           11                 11
# 14  Bell       27         14            7                 7
# 15  Bexar      29         15            8                 8
# 16  Blanco     31         16            7                 7
# 17  Borden     33         17            9                 9/10
# 18  Bosque     35         18            7                 7
# 19  Bowie      37         19            4                 4/5N
# 20  Brazoria   39         20            6                 6/5S
# 21  Brazos     41         21            7                 7
# 22  Brewster   43         22           10                 9/10
# 23  Briscoe    45         23            1                 1
# 24  Brooks     47         24           11                 11
# 25  Brown      49         25            2                 2/3
# 26  Burleson   51         26            7                 7
# 27  Burnet     53         27            7                 7
# 28  Caldwell   55         28            7                 7
# 29  Calhoun    57         29            8                 8
# 30  Callahan   59         30            2                 2/3
# ⋮   ⋮          ⋮          ⋮            ⋮                  ⋮
# 225 Titus      449        225           4                 4/5N
# 226 Tom Green  451        226           9                 9/10
# 227 Travis     453        227           7                 7
# 228 Trinity    455        228           5                 4/5N
# 229 Tyler      457        229           5                 4/5N
# 230 Upshur     459        230           4                 4/5N
# 231 Upton      461        231           9                 9/10
# 232 Uvalde     463        232           8                 8
# 233 Val Verde  465        233           8                 8
# 234 Van Zandt  467        234           4                 4/5N
# 235 Victoria   469        235           8                 8
# 236 Walker     471        236           6                 6/5S
# 237 Waller     473        237           6                 6/5S
# 238 Ward       475        238           9                 9/10
# 239 Washington 477        239           7                 7
# 240 Webb       479        240          11                 11
# 241 Wharton    481        241           6                 6/5S
# 242 Wheeler    483        242           1                 1
# 243 Wichita    485        243           2                 2/3
# 244 Wilbarger  487        244           2                 2/3
# 245 Willacy    489        245          11                 11
# 246 Williamson 491        246           7                 7
# 247 Wilson     493        247           8                 8
# 248 Winkler    495        248           9                 9/10
# 249 Wise       497        249           3                 2/3
# 250 Wood       499        250           4                 4/5N
# 251 Yoakum     501        251           1                 1
# 252 Young      503        252           2                 2/3
# 253 Zapata     505        253          11                 11
# 254 Zavala     507        254           8                 8
#     MetropolitanStatisticalArea_MSA  MetropolitanDivisions   MetroArea
# 1   --                               --                      Non-Metro
# 2   --                               --                      Non-Metro
# 3   --                               --                      Non-Metro
# 4   Corpus Christi                   --                      Metro
# 5   Wichita Falls                    --                      Metro
# 6   Amarillo                         --                      Metro
# 7   San Antonio-New Braunfels        --                      Metro
# 8   Houston-The Woodlands-Sugar Land --                      Metro
# 9   --                               --                      Non-Metro
# 10  San Antonio-New Braunfels        --                      Metro
# 11  Austin-Round Rock                --                      Metro
# 12  --                               --                      Non-Metro
# 13  --                               --                      Non-Metro
# 14  Killeen-Temple                   --                      Metro
# 15  San Antonio-New Braunfels        --                      Metro
# 16  --                               --                      Non-Metro
# 17  --                               --                      Non-Metro
# 18  --                               --                      Non-Metro
# 19  Texarkana                        --                      Metro
# 20  Houston-The Woodlands-Sugar Land --                      Metro
# 21  College Station-Bryan            --                      Metro
# 22  --                               --                      Non-Metro
# 23  --                               --                      Non-Metro
# 24  --                               --                      Non-Metro
# 25  --                               --                      Non-Metro
# 26  College Station-Bryan            --                      Metro
# 27  --                               --                      Non-Metro
# 28  Austin-Round Rock                --                      Metro
# 29  --                               --                      Non-Metro
# 30  Abilene                          --                      Metro
# ⋮   ⋮                                ⋮                       ⋮
# 225 --                               --                      Non-Metro
# 226 San Angelo                       --                      Metro
# 227 Austin-Round Rock                --                      Metro
# 228 --                               --                      Non-Metro
# 229 --                               --                      Non-Metro
# 230 Longview                         --                      Metro
# 231 --                               --                      Non-Metro
# 232 --                               --                      Non-Metro
# 233 --                               --                      Non-Metro
# 234 --                               --                      Non-Metro
# 235 Victoria                         --                      Metro
# 236 --                               --                      Non-Metro
# 237 Houston-The Woodlands-Sugar Land --                      Metro
# 238 --                               --                      Non-Metro
# 239 --                               --                      Non-Metro
# 240 Laredo                           --                      Metro
# 241 --                               --                      Non-Metro
# 242 --                               --                      Non-Metro
# 243 Wichita Falls                    --                      Metro
# 244 --                               --                      Non-Metro
# 245 --                               --                      Non-Metro
# 246 Austin-Round Rock                --                      Metro
# 247 San Antonio-New Braunfels        --                      Metro
# 248 --                               --                      Non-Metro
# 249 Dallas-Fort Worth-Arlington      Fort Worth-Arlington MD Metro
# 250 --                               --                      Non-Metro
# 251 --                               --                      Non-Metro
# 252 --                               --                      Non-Metro
# 253 --                               --                      Non-Metro
# 254 --                               --                      Non-Metro
#     NCHSUrbanRuralClassification_2006 NCHSUrbanRuralClassification_2013
# 1   Micropolitan                      Micropolitan
# 2   Micropolitan                      Micropolitan
# 3   Micropolitan                      Micropolitan
# 4   Medium Metro                      Medium Metro
# 5   Small Metro                       Small Metro
# 6   Small Metro                       Medium Metro
# 7   Large Fringe Metro                Large Fringe Metro
# 8   Large Fringe Metro                Large Fringe Metro
# 9   Noncore                           Non-core
# 10  Large Fringe Metro                Large Fringe Metro
# 11  Large Fringe Metro                Large Fringe Metro
# 12  Noncore                           Non-core
# 13  Micropolitan                      Micropolitan
# 14  Medium Metro                      Medium Metro
# 15  Large Central Metro               Large Central Metro
# 16  Noncore                           Non-core
# 17  Noncore                           Non-core
# 18  Noncore                           Non-core
# 19  Small Metro                       Small Metro
# 20  Large Fringe Metro                Large Fringe Metro
# 21  Small Metro                       Small Metro
# 22  Noncore                           Non-core
# 23  Noncore                           Non-core
# 24  Noncore                           Non-core
# 25  Micropolitan                      Micropolitan
# 26  Small Metro                       Small Metro
# 27  Noncore                           Non-core
# 28  Large Fringe Metro                Large Fringe Metro
# 29  Small Metro                       Micropolitan
# 30  Small Metro                       Small Metro
# ⋮   ⋮                                 ⋮
# 225 Micropolitan                      Micropolitan
# 226 Small Metro                       Small Metro
# 227 Large Central Metro               Large Central Metro
# 228 Noncore                           Micropolitan
# 229 Noncore                           Non-core
# 230 Small Metro                       Small Metro
# 231 Noncore                           Non-core
# 232 Micropolitan                      Micropolitan
# 233 Micropolitan                      Micropolitan
# 234 Noncore                           Non-core
# 235 Small Metro                       Small Metro
# 236 Micropolitan                      Micropolitan
# 237 Large Fringe Metro                Large Fringe Metro
# 238 Noncore                           Non-core
# 239 Micropolitan                      Micropolitan
# 240 Small Metro                       Medium Metro
# 241 Micropolitan                      Micropolitan
# 242 Noncore                           Non-core
# 243 Small Metro                       Small Metro
# 244 Micropolitan                      Micropolitan
# 245 Micropolitan                      Micropolitan
# 246 Large Fringe Metro                Large Fringe Metro
# 247 Large Fringe Metro                Large Fringe Metro
# 248 Noncore                           Non-core
# 249 Large Fringe Metro                Large Fringe Metro
# 250 Noncore                           Non-core
# 251 Noncore                           Non-core
# 252 Noncore                           Non-core
# 253 Noncore                           Micropolitan
# 254 Noncore                           Non-core
